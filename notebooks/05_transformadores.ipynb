# %% [markdown]
# Os modelos baseados em transformadores tem demonstrado elevado desempenho em v ˆ arias ´
# tarefas de Processamento Computacional da L´ıngua, incluindo a analise de sentimento. Ex- ´
# plore o uso de um destes modelos, pre-treinado para an ´ alise de sentimento. Pode usar, por ´
# exemplo, o modelo distilbert-base-uncased-finetuned-sst-2-english dispon´ıvel na plataforma Hugging Face. Pode seguir a receitadispon´ıvel na mesma plataforma.
